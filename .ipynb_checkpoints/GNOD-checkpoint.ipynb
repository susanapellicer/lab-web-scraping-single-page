# %% [markdown]
# # Lab | Web Scraping Single Page (GNOD part 1)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# 1. find url and store it in a variable
url = "https://www.popvortex.com/music/charts/top-100-songs.php"

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
#response.content
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta charset="utf-8"><title>iTunes Top 100 Songs Chart 2023</title><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="description" content="iTunes top 100 songs chart list. The most popular hit music and trending songs of 2023. Chart of today\'s current iTunes top 100 songs is updated daily."><meta property="og:title" content="iTunes Top 100 Songs Chart 2023"/><script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-8935069470799160"\n     crossorigin="anonymous"></script><meta property="og:description" content="Chart of the top 100 songs on iTunes. Chart list of the top 100 song downloads of 2023 is updated daily."/><meta property="og:type" content="article"/><meta property="og:image" content="https://www.popvortex.com/images/logo-facebook.png"/><meta property="og:site_name" content="PopVortex"/><meta property="og:url" content="https://www.popvortex.com/music/charts/top-100-so
# ...

# %%
len(response.content)
# Out:
# 366074

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
# soup

# %%
soup.select("#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p")
# Out:
# [<p class="title-artist"><cite class="title">Fast Car</cite><em class="artist">Luke Combs</em></p>]

# %%
soup.select("p.title-artist")
# Out:
# [<p class="title-artist"><cite class="title">Fast Car</cite><em class="artist">Luke Combs</em></p>,
#  <p class="title-artist"><cite class="title">Take Two</cite><em class="artist">BTS</em></p>,
#  <p class="title-artist"><cite class="title">Last Night</cite><em class="artist">Morgan Wallen</em></p>,
#  <p class="title-artist"><cite class="title">Need A Favor</cite><em class="artist">Jelly Roll</em></p>,
#  <p class="title-artist"><cite class="title">81 Million Votes, My Ass</cite><em class="artist">The Truth Bombers &amp; Kari Lake</em></p>,
#  <p class="title-artist"><cite class="title">Save Me (with Lainey Wilson)</cite><em class="artist">Jelly Roll</em></p>,
#  <p class="title-artist"><cite class="title">Son</cite><em class="artist">Mitch Rossell</em></p>,
#  <p class="title-artist"><cite class="title">Flowers</cite><em class="artist">Miley Cyrus</em></p>,
#  <p class="title-artist"><cite class="title">Thank God I Do</cite><em class="artist">Lauren Daigle</em></p>,
# ...

# %%
soup.select("body > div.container > div:nth-child(4) > div.col-xs-12.col-md-8 > div.chart-wrapper p cite")
# Out:
# [<cite class="title">Fast Car</cite>,
#  <cite class="title">Take Two</cite>,
#  <cite class="title">Last Night</cite>,
#  <cite class="title">Need A Favor</cite>,
#  <cite class="title">81 Million Votes, My Ass</cite>,
#  <cite class="title">Save Me (with Lainey Wilson)</cite>,
#  <cite class="title">Son</cite>,
#  <cite class="title">Flowers</cite>,
#  <cite class="title">Thank God I Do</cite>,
#  <cite class="title">Rode Hard</cite>,
#  <cite class="title">Calm Down</cite>,
#  <cite class="title">Bust a Move</cite>,
#  <cite class="title">Son Of A Sinner</cite>,
#  <cite class="title">Thinkin’ Bout Me</cite>,
#  <cite class="title">Funky Cold Medina</cite>,
#  <cite class="title">Dance The Night</cite>,
#  <cite class="title">Area Codes</cite>,
#  <cite class="title">Pound Town 2</cite>,
#  <cite class="title">Stand By Me (feat. Morgan Wallen)</cite>,
#  <cite class="title">Thicc As Thieves</cite>,
#  <cite class="title">All My Life (feat. J. Cole)</cite>,
# ...

# %%
soup.select("p.title-artist")[0]
soup.select("p.title-artist")[0].get_text()
# Out:
# 'Fast CarLuke Combs'

# %%
titles = soup.select("div.col-sm-8 p")

title_list = []

for title in titles:
    title_text = title.find(class_="title").get_text()
    title_list.append(title_text)

print(title_list)
# Out:
# ['Fast Car', 'Take Two', 'Last Night', 'Need A Favor', '81 Million Votes, My Ass', 'Save Me (with Lainey Wilson)', 'Son', 'Flowers', 'Thank God I Do', 'Rode Hard', 'Calm Down', 'Bust a Move', 'Son Of A Sinner', 'Thinkin’ Bout Me', 'Funky Cold Medina', 'Dance The Night', 'Area Codes', 'Pound Town 2', 'Stand By Me (feat. Morgan Wallen)', 'Thicc As Thieves', 'All My Life (feat. J. Cole)', 'TRUSTFALL', 'Wild Thing', 'Let Me In', 'VULGAR', 'Cruel Summer', 'Thought You Should Know', 'Favorite Song', 'Heart Like A Truck', 'Dancin’ In The Country', 'Thank God', 'Love You Anyway', 'Karma', 'Anti-Hero', 'Religiously', 'If You Were Mine', 'Eyes Closed', 'Heaven', 'Rock and A Hard Place', 'One Thing At A Time', 'To the Bar', 'Mourning', "Something in the Orange (Z&E's Version)", 'Popular', 'Am I Dreaming', 'Praise You Anywhere', 'Bury Me in Georgia (Single Edit)', 'Watermelon Moonshine', 'Next Thing You Know', 'Can She Have This Dance', 'Tennessee Orange', 'Chemical', 'Dial Drunk', 'Tennessee Wh
# ...

# %%
artist = soup.select("div.col-sm-8 p")

artist_list = []

for artist in artist:
    artist_text = artist.find(class_="artist").get_text()
    artist_list.append(artist_text)

print(artist_list)
# Out:
# ['Luke Combs', 'BTS', 'Morgan Wallen', 'Jelly Roll', 'The Truth Bombers & Kari Lake', 'Jelly Roll', 'Mitch Rossell', 'Miley Cyrus', 'Lauren Daigle', 'Danae Hays', 'Rema & Selena Gomez', 'Young MC', 'Jelly Roll', 'Morgan Wallen', 'Tone-Loc', 'Dua Lipa', 'Kali', 'Sexyy Red, Nicki Minaj & Tay Keith', 'Lil Durk', 'Lauren Alaina & Lainey Wilson', 'Lil Durk', 'P!nk', 'Tone-Loc', 'EXO', 'Sam Smith & Madonna', 'Taylor Swift', 'Morgan Wallen', 'Toosii', 'Lainey Wilson', 'Tyler Hubbard', 'Kane Brown & Katelyn Brown', 'Luke Combs', 'Taylor Swift', 'Taylor Swift', 'Bailey Zimmerman', 'Miranda Lambert & Leon Bridges', 'Ed Sheeran', 'Niall Horan', 'Bailey Zimmerman', 'Morgan Wallen', 'Cooper Alan', 'Post Malone', 'Zach Bryan', 'The Weeknd, Playboi Carti & Madonna', 'Metro Boomin, A$AP Rocky & Roisee', 'Brandon Lake', 'Kane Brown', 'Lainey Wilson', 'Jordan Davis', 'Drew Baldridge', 'Megan Moroney', 'Post Malone', 'Noah Kahan', 'Chris Stapleton', 'David Kushner', 'Tracy Chapman', 'Sia', 'Morgan Wall
# ...

# %%
data = pd.DataFrame({"title":title_list,
                       "artist":artist_list
                      })

# %%
data
# Out:
#                                             title  \
# 0                                        Fast Car
# 1                                        Take Two
# 2                                      Last Night
# 3                                    Need A Favor
# 4                        81 Million Votes, My Ass
# ..                                            ...
# 95  Sunflower (Spider-Man: Into the Spider-Verse)
# 96                                 Beat You There
# 97                                 'Til You Can't
# 98       Put It On Da Floor Again (feat. Cardi B)
# 99                                    Chasin' You
#
#                            artist
# 0                      Luke Combs
# 1                             BTS
# 2                   Morgan Wallen
# 3                      Jelly Roll
# 4   The Truth Bombers & Kari Lake
# ..                            ...
# 95         Post Malone & Swae Lee
# 96                   Will Dempsey
# 97                   Cody Johnson
# ...

# %% [markdown]
# # Lab | Web Scraping Multiple Pages

# %% [markdown]
# ### Instructions Part 1

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url2 = "https://en.wikipedia.org/wiki/List_of_rock_instrumentals"

# %%
response2 = requests.get(url2)
response2.status_code
# Out:
# 200

# %%
soup2 = BeautifulSoup(response2.content, "html.parser")

# %%
soup2
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of rock instrumentals - Wikipedia</title>
# ...

# %%
soup2.select("#mw-content-text > div.mw-parser-output > table:nth-child(8)")
# Out:
# [<table class="wikitable sortable">
#  <tbody><tr>
#  <th>Artist
#  </th>
#  <th>Song title
#  </th>
#  <th>Date
#  </th>
#  <th>Highest position<br/> on US charts
#  </th>
#  <th>Highest position<br/> on UK charts
#  </th>
#  <th>Highest position<br/> on R&amp;B charts
#  </th>
#  <th>Miscellaneous
#  </th></tr>
#  <tr>
#  <td><a href="/wiki/Bill_Justis" title="Bill Justis">Bill Justis</a>
#  </td>
#  <td>"<a href="/wiki/Raunchy_(instrumental)" title="Raunchy (instrumental)">Raunchy</a>"
#  </td>
#  <td>1957
#  </td>
#  <td>#3<sup class="reference" id="cite_ref-FOOTNOTEWhitburn1992254_4-0"><a href="#cite_note-FOOTNOTEWhitburn1992254-4">[4]</a></sup>
#  </td>
#  <td>#24<sup class="reference" id="cite_ref-FOOTNOTEBrown2002538_5-0"><a href="#cite_note-FOOTNOTEBrown2002538-5">[5]</a></sup>
#  </td>
#  <td>#1<sup class="reference" id="cite_ref-FOOTNOTEWhitburn2006306_6-0"><a href="#cite_note-FOOTNOTEWhitburn2006306-6">[6]</a></sup>
#  </td>
#  <td>
#  </td></tr>
#  <tr>
# ...

# %%
# soup2.select("table")[0]

# %%
prestab = soup2.select("table")[0]
prestab
prestab.select("tr td a")
# Out:
# [<a href="/wiki/Bill_Justis" title="Bill Justis">Bill Justis</a>,
#  <a href="/wiki/Raunchy_(instrumental)" title="Raunchy (instrumental)">Raunchy</a>,
#  <a href="#cite_note-FOOTNOTEWhitburn1992254-4">[4]</a>,
#  <a href="#cite_note-FOOTNOTEBrown2002538-5">[5]</a>,
#  <a href="#cite_note-FOOTNOTEWhitburn2006306-6">[6]</a>,
#  <a href="/wiki/Ernie_Freeman" title="Ernie Freeman">Ernie Freeman</a>,
#  <a href="#cite_note-7">[7]</a>,
#  <a href="/wiki/The_Champs" title="The Champs">The Champs</a>,
#  <a class="mw-redirect" href="/wiki/Tequila_(Champs_song)" title="Tequila (Champs song)">Tequila</a>,
#  <a href="#cite_note-FOOTNOTEWhitburn199288-8">[8]</a>,
#  <a href="#cite_note-FOOTNOTEBrown2002201-9">[9]</a>,
#  <a href="#cite_note-FOOTNOTEWhitburn200694-10">[10]</a>,
#  <a href="/wiki/Duane_Eddy" title="Duane Eddy">Duane Eddy</a>,
#  <a class="mw-redirect" href="/wiki/Link_Wray_%26_His_Ray_Men" title="Link Wray &amp; His Ray Men">Link Wray &amp; His Ray Men</a>,
# ...

# %%
soup2.select("#mw-content-text > div.mw-parser-output > table:nth-child(8) a")[0].title
#soup2.select("#mw-content-text > div.mw-parser-output > table:nth-child(8) a") #[0].get_text()

# %%
soup2.select("#mw-content-text > div.mw-parser-output > table:nth-child(8) > tbody > tr:nth-child(1) > td:nth-child(2)")
# Out:
# []

# %%
#mw-content-text > div.mw-parser-output > table:nth-child(8) > tbody > tr:nth-child(1) > td:nth-child(2)

# %%
#mw-content-text > div.mw-parser-output > table:nth-child(8) > tbody > tr:nth-child(1) > td:nth-child(2) > a

# %%
prestab = soup2.select("#mw-content-text > div.mw-parser-output > table:nth-child(8) a")[0]
prestab
prestab.select("tr td li")
# Out:
# []

# %%
prestab.select("th td a")
# Out:
# []

# %%
artists = []
song_titles = []

for row in prestab.select("tr"):
    cells = row.select("td")
    if len(cells) >= 2:
        artist = cells[0].text.strip()
        song_title = cells[1].text.strip()
        artists.append(artist)
        song_titles.append(song_title)

# %%
artists
# Out:
# ['Bill Justis',
#  'Ernie Freeman',
#  'The Champs',
#  'Duane Eddy',
#  'The Champs',
#  'Link Wray & His Ray Men',
#  'Duane Eddy',
#  'Duane Eddy',
#  'The Champs',
#  'Duane Eddy',
#  'Link Wray & His Ray Men',
#  "The Rockin' R's",
#  'Duane Eddy',
#  'The Virtues',
#  'Dave "Baby" Cortez',
#  'Johnny and the Hurricanes',
#  'The Wailers',
#  'Preston Epps',
#  'Duane Eddy',
#  'Johnny and the Hurricanes',
#  'The Wailers',
#  'Sandy Nelson',
#  'Santo & Johnny',
#  'Santo & Johnny',
#  'Duane Eddy',
#  'Johnny And The Hurricanes',
#  'The Fireballs',
#  'The Champs',
#  'Johnny and the Hurricanes',
#  "Bill Black's Combo",
#  "Bill Black's Combo",
#  'Duane Eddy',
#  'Duane Eddy',
#  'Johnny and the Hurricanes',
#  'Duane Eddy',
#  'Floyd Cramer',
#  'The Shadows',
#  'The Shadows',
#  'The Ventures',
#  'Duane Eddy',
#  'B. Bumble and the Stingers',
#  'The Fireballs',
#  'Kokomo',
#  'The Mar-Keys',
#  'Sandy Nelson',
#  'The Shadows',
#  'The Shadows',
#  'The Shadows',
# ...

# %%
song_titles
# Out:
# ['"Raunchy"',
#  '"Raunchy"',
#  '"Tequila"',
#  '"Moovin\' N\' Groovin\'"',
#  '"El Rancho Rock"',
#  '"Rumble"',
#  '"Rebel Rouser"',
#  '"Ramrod"',
#  '"Chariot Rock"',
#  '"Cannonball"',
#  '"Raw-Hide"',
#  '"The Beat"',
#  '"Yep!"',
#  '"Guitar Boogie Shuffle"',
#  '"The Happy Organ"',
#  '"Crossfire"',
#  '"Tall Cool One"',
#  '"Bongo Rock"',
#  '"Forty Miles of Bad Road"',
#  '"Red River Rock"',
#  '"Mau-Mau"',
#  '"Teen Beat"',
#  '"Sleep Walk"',
#  '"Tear Drop"',
#  '"Some Kind-A Earthquake"',
#  '"Reveille Rock"',
#  '"Bulldog"',
#  '"Too Much Tequila"',
#  '"Beatnik Fly"',
#  '"White Silver Sands"',
#  '"Don\'t Be Cruel"',
#  '"Shazam"',
#  '"Because They\'re Young"',
#  '"Rocking Goose"',
#  '"Peter Gunn"',
#  '"Last Date"',
#  '"Apache"',
#  '"Man of Mystery"',
#  '"Walk, Don\'t Run"',
#  '"Pepe"',
#  '"Bumble Boogie"',
#  '"Quite a Party"',
#  '"Asia Minor"',
#  '"Last Night"',
#  '"Let There Be Drums"',
#  '"F.B.I."',
#  '"The Frightened City"',
#  '"Kon-Tiki"',
# ...

# %%
data1 = {"Artist": artists, "Song Title": song_titles}
data1 = pd.DataFrame(data1)
data1
# Out:
#                     Artist              Song Title
# 0              Bill Justis               "Raunchy"
# 1            Ernie Freeman               "Raunchy"
# 2               The Champs               "Tequila"
# 3               Duane Eddy   "Moovin' N' Groovin'"
# 4               The Champs        "El Rancho Rock"
# ..                     ...                     ...
# 76           Fleetwood Mac             "Albatross"
# 77           Hugh Masekela  "Grazing in the Grass"
# 78          Mason Williams         "Classical Gas"
# 79  Booker T. & the M.G.'s         "Time Is Tight"
# 80            The Ventures         "Hawaii Five-O"
#
# [81 rows x 2 columns]
